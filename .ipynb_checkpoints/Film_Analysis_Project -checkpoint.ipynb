# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction:" data-toc-modified-id="Introduction:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction:</a></span><ul class="toc-item"><li><span><a href="#Citation" data-toc-modified-id="Citation-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Citation</a></span></li><li><span><a href="#Overview" data-toc-modified-id="Overview-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Overview</a></span></li><li><span><a href="#Business-Understanding:" data-toc-modified-id="Business-Understanding:-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Business Understanding:</a></span></li></ul></li><li><span><a href="#Cleaning-the-Data:" data-toc-modified-id="Cleaning-the-Data:-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Cleaning the Data:</a></span><ul class="toc-item"><li><span><a href="#Importing-the-libraries-and-various-data-files" data-toc-modified-id="Importing-the-libraries-and-various-data-files-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Importing the libraries and various data files</a></span></li><li><span><a href="#Assigning-genres-to-the-genres-column" data-toc-modified-id="Assigning-genres-to-the-genres-column-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Assigning genres to the genres column</a></span></li><li><span><a href="#Making-merges-to-bring-the-data-together." data-toc-modified-id="Making-merges-to-bring-the-data-together.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Making merges to bring the data together.</a></span></li><li><span><a href="#Limiting-the-data-on-runtime" data-toc-modified-id="Limiting-the-data-on-runtime-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Limiting the data on runtime</a></span></li><li><span><a href="#Dropping-unnecessary-columns" data-toc-modified-id="Dropping-unnecessary-columns-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Dropping unnecessary columns</a></span></li><li><span><a href="#Formatting-the-Remaining-Data" data-toc-modified-id="Formatting-the-Remaining-Data-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Formatting the Remaining Data</a></span></li><li><span><a href="#Checking-for-Null-Values" data-toc-modified-id="Checking-for-Null-Values-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Checking for Null Values</a></span></li><li><span><a href="#Removing-duplicates" data-toc-modified-id="Removing-duplicates-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Removing duplicates</a></span></li></ul></li><li><span><a href="#Recommendations:" data-toc-modified-id="Recommendations:-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Recommendations:</a></span><ul class="toc-item"><li><span><a href="#Genre-recommendations" data-toc-modified-id="Genre-recommendations-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Genre recommendations</a></span><ul class="toc-item"><li><span><a href="#CITATION:-color-coding" data-toc-modified-id="CITATION:-color-coding-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>CITATION: color coding</a></span></li></ul></li><li><span><a href="#Release-Date" data-toc-modified-id="Release-Date-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Release Date</a></span></li><li><span><a href="#Runtime-of-Film" data-toc-modified-id="Runtime-of-Film-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Runtime of Film</a></span></li></ul></li><li><span><a href="#Conclusion:" data-toc-modified-id="Conclusion:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Conclusion:</a></span><ul class="toc-item"><li><span><a href="#Three-Business-Recommendations:" data-toc-modified-id="Three-Business-Recommendations:-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Three Business Recommendations:</a></span></li><li><span><a href="#Future-Work" data-toc-modified-id="Future-Work-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Future Work</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Introduction:

# %% [markdown]
# ## Citation
#
# Much of this project and its code come directly from https://github.com/ElyLin/MovieAnalysisProject where I was a contributor. After being a contributor to the group project, I wanted to go back and re-explore my process and analysis on my own.
#
# In my presentation, I recommend making films based on DOOM, Wolfenstein, The Elder Scrolls: Skyrim, Fallout and Dishonored, all Bethesda games that Microsoft bought the rights to in 2020. https://news.microsoft.com/2020/09/21/microsoft-to-acquire-zenimax-media-and-its-game-publisher-bethesda-softworks/

# %% [markdown]
# ## Overview
#
# Microsoft sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don't know anything about creating movies. You are charged with exploring what types of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the head of Microsoft's new movie studio can use to help decide what type of films to create.

# %% [markdown]
# ## Business Understanding:
#
# In this project, I hope to make a recommendation to Microsoft based on the Net Profit of the films. I'm using Net Profit as opposed to using Return on Investment (ROI) as my main financial data metric since Microsoft is already so large and successful that they can afford to put some investment into their films. They don't need to focus on getting a high profit from a low-budget film, they don't need to be so conservative with their investments. They can instead safely invest by following my recommendations.
#
# I will be making recommendations based on the answers to the following questions:
#
# 1) What is the best genre to make a film in?
#
# 2) What is the best time to release the film?
#
# 3) What is the ideal runtime of a film?

# %% [markdown]
# # Cleaning the Data:

# %% [markdown]
# ## Importing the libraries and various data files

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# these are the various libraries we will need

# %%
# here is the raw data I will be using

movie_budgets_df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')   
# this csv is from The Numbers "where Data and the Movie Buisness meet"
# https://www.the-numbers.com/
title_basics = pd.read_csv('zippedData/imdb.title.basics.csv.gz')   
title_ratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz') 
# those csvs are from https://www.imdb.com/, an amazon company. IMDB stands 
# for Internet Movie Data Base
tmdb = pd.read_csv('zippedData/tmdb.movies.csv.gz')
# this csv is from The Movie Database which prides itself on being 
# community built https://www.themoviedb.org/?language=en-US

# %% [markdown]
# ## Assigning genres to the genres column

# %%
# firstly, the tmbd database has it's genre's encoded so we must decode the 
# genre's using the below dictionary

genres={'28':"Action",
'12':"Adventure",
'16':"Animation",
'35':"Comedy",
'80':"Crime",
'99':"Documentary",
'18':"Drama",
'10751':"Family",
'14':"Fantasy",
'36':"History",
'27':"Horror",
'10402':"Music",
'9648':"Mystery",
'10749':"Romance",
'878':"Science Fiction",
'10770':"TV Movie",
'53':"Thriller",
'10752':"War",
'37':"Western"}

tmdb['genre_ids'] = tmdb['genre_ids'].replace(pd.Series(genres).astype(str), 
                                              regex=True)
tmdb['genre_ids']=tmdb['genre_ids'].str.strip('[]').str.split(', ')

# creating a dictionary and using the key, values pairs to decode the genres

# %% [markdown]
# ## Making merges to bring the data together.

# %%
# secondly, we must merge the two IMDB dataframes

title_master = title_basics.merge(title_ratings, how='inner')
title_master.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
# making the title and tconst ID part of the same object so I can drop 
# douplicates effectively

title_master['title_and_id'] = title_master['primary_title'] +' id ' + \
title_master['tconst']

# %%
# we must merge the tmdb database with the imdb database. 
# we chose to do an inner merge, here because we 
# are only interested in the movies that these dataframes have in common

tmdb_and_imdb = tmdb.merge(title_master, how = 'inner')
tmdb_and_imdb.head()
# Out:
#    Unnamed: 0                                genre_ids     id  \
# 0           0             [Adventure, Fantasy, Family]  12444
# 1           1  [Fantasy, Adventure, Animation, Family]  10191
# 2           2     [Adventure, Action, Science Fiction]  10138
# 3           4     [Action, Science Fiction, Adventure]  27205
# 4           5             [Adventure, Fantasy, Family]  32657
#
#   original_language                                     original_title  \
# 0                en       Harry Potter and the Deathly Hallows: Part 1
# 1                en                           How to Train Your Dragon
# 2                en                                         Iron Man 2
# 3                en                                          Inception
# 4                en  Percy Jackson & the Olympians: The Lightning T...
#
#    popularity release_date                                              title  \
# 0      33.533   2010-11-19       Harry Potter and the Deathly Hallows: Part 1
# ...

# %%
# the next dataframe we want to fold in has the column "movie" but we want 
# to rename it to title so the merge can happen on the title of the film, 
# so we must rename the column

movie_budgets_df = movie_budgets_df.rename(columns={'movie':'title'})

# %%
# now we want to merge the fincial dataframe from The Numbers 
# with all the others based on Title, so we specify that 
# with the on = 'title'

master_unclean = tmdb_and_imdb.merge\
(movie_budgets_df, on = 'title', how = 'inner')
master_unclean.head()
# Out:
#    Unnamed: 0                                genre_ids   id_x  \
# 0           1  [Fantasy, Adventure, Animation, Family]  10191
# 1           2     [Adventure, Action, Science Fiction]  10138
# 2           4     [Action, Science Fiction, Adventure]  27205
# 3           5             [Adventure, Fantasy, Family]  32657
# 4           7              [Animation, Family, Comedy]  10193
#
#   original_language                                     original_title  \
# 0                en                           How to Train Your Dragon
# 1                en                                         Iron Man 2
# 2                en                                          Inception
# 3                en  Percy Jackson & the Olympians: The Lightning T...
# 4                en                                        Toy Story 3
#
#    popularity release_date_x  \
# 0      28.734     2010-03-26
# 1      28.515     2010-05-07
# 2      27.920     2010-07-16
# 3      26.691     2010-02-11
# ...

# %%
# let's take a look at the amount of information we have now and the types 
# of information in our columns we can see where we have duplicate columns, 
# we now have x and y versions to distinguish them from each other
# runtime_minutes and genres are the only columns that do not have 
# 16669 non null values after this merge

master_unclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2959 entries, 0 to 2958
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2959 non-null   int64
#  1   genre_ids          2959 non-null   object
#  2   id_x               2959 non-null   int64
#  3   original_language  2959 non-null   object
#  4   original_title     2959 non-null   object
#  5   popularity         2959 non-null   float64
#  6   release_date_x     2959 non-null   object
#  7   title              2959 non-null   object
#  8   vote_average       2959 non-null   float64
#  9   vote_count         2959 non-null   int64
#  10  tconst             2959 non-null   object
#  11  primary_title      2959 non-null   object
#  12  start_year         2959 non-null   int64
#  13  runtime_minutes    2864 non-null   float64
#  14  genres             2952 non-null   object
#  15  averagerating      2959 non-null   float64
# ...

# %% [markdown]
# ## Limiting the data on runtime

# %%
# now we want to exclude movies from this master dataframe which are less 
# than 45 min and more than three hours, because we want to base the 
# recomendations on films that are typically seen in the movie theater
# and put that information on a new dataframe called run_time

run_time = master_unclean.loc[(master_unclean['runtime_minutes'] > 45) \
                              & (master_unclean['runtime_minutes'] < 180)]
run_time.head()
# Out:
#    Unnamed: 0                                genre_ids   id_x  \
# 0           1  [Fantasy, Adventure, Animation, Family]  10191
# 1           2     [Adventure, Action, Science Fiction]  10138
# 2           4     [Action, Science Fiction, Adventure]  27205
# 3           5             [Adventure, Fantasy, Family]  32657
# 4           7              [Animation, Family, Comedy]  10193
#
#   original_language                                     original_title  \
# 0                en                           How to Train Your Dragon
# 1                en                                         Iron Man 2
# 2                en                                          Inception
# 3                en  Percy Jackson & the Olympians: The Lightning T...
# 4                en                                        Toy Story 3
#
#    popularity release_date_x  \
# 0      28.734     2010-03-26
# 1      28.515     2010-05-07
# 2      27.920     2010-07-16
# 3      26.691     2010-02-11
# ...

# %% [markdown]
# ## Dropping unnecessary columns

# %%
# here, we want to drop some columns where the information is irrelivant 
# or duplicated. I'm dripping id_x and id_y since I don't need another unqie 
# identifyer,  title, original title since I already have the title column I 
# need,  start year, year and release_date_x since I already have a datetime 
# column, genres since the genre_ids column I already have is more robust, 
# and all the rating a popularity information since I won't be using that data 
# for my analysis

df = master_unclean.drop\
(['Unnamed: 0', 'id_x', 'original_title', 'start_year', 'id_y',\
'genres', 'release_date_x', 'primary_title', 'original_language', \
'popularity', 'vote_average', 'vote_count', 'numvotes', 'averagerating',
  'title', 'tconst'],
 axis = 1)

# %%
#let's take a look at where our dataframe is right now

df.head()
# Out:
#                                  genre_ids  runtime_minutes  \
# 0  [Fantasy, Adventure, Animation, Family]             98.0
# 1     [Adventure, Action, Science Fiction]            124.0
# 2     [Action, Science Fiction, Adventure]            148.0
# 3             [Adventure, Fantasy, Family]            118.0
# 4              [Animation, Family, Comedy]            103.0
#
#                                         title_and_id release_date_y  \
# 0              How to Train Your Dragon id tt0892769   Mar 26, 2010
# 1                            Iron Man 2 id tt1228705    May 7, 2010
# 2                             Inception id tt1375666   Jul 16, 2010
# 3  Percy Jackson & the Olympians: The Lightning T...   Feb 12, 2010
# 4                           Toy Story 3 id tt0435761   Jun 18, 2010
#
#   production_budget domestic_gross worldwide_gross
# 0      $165,000,000   $217,581,232    $494,870,992
# 1      $170,000,000   $312,433,331    $621,156,389
# ...

# %% [markdown]
# ## Formatting the Remaining Data

# %%
# this function will take a string value with commas and dollar signs and 
# return an integer value in a format that I can do math upon 

def reformat(string_to_money):
    string_to_money = string_to_money.replace(',', '').replace('$', '')
    string_to_money = int(string_to_money)
    return string_to_money

# %%
#reformatting the production budget, domestic gross and worldwide gross columns 

df['production_budget'] = df['production_budget'].map(reformat)
df['domestic_gross'] = df['domestic_gross'].map(reformat)
df['worldwide_gross'] =df['worldwide_gross'].map(reformat)

# %%
#checking to make sure my finacial data is in integer form

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2959 entries, 0 to 2958
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          2959 non-null   object
#  1   runtime_minutes    2864 non-null   float64
#  2   title_and_id       2959 non-null   object
#  3   release_date_y     2959 non-null   object
#  4   production_budget  2959 non-null   int64
#  5   domestic_gross     2959 non-null   int64
#  6   worldwide_gross    2959 non-null   int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 184.9+ KB

# %%
# creating total gross, net_profit and ROI as finacial metrics. I will be using 
# net profit as my main metric but I wanted to create total gross and ROI 
# for any additional analysis in my conclusion 

df['total_gross'] = df['domestic_gross'] + df['worldwide_gross']
df['net_profit']= df['total_gross'] - df['production_budget'] 
df['ROI'] = (df['net_profit'] / df['production_budget']) * 100

# %% [markdown]
# ## Checking for Null Values

# %%
# seeing how many columns have null values

df.isna().sum()
# Out:
# genre_ids             0
# runtime_minutes      95
# title_and_id          0
# release_date_y        0
# production_budget     0
# domestic_gross        0
# worldwide_gross       0
# total_gross           0
# net_profit            0
# ROI                   0
# dtype: int64

# %% [markdown]
# I'm going to drop the rows where the
# runtime data is missing, it's a small section of my dataset and since I will be making recommendations based on runtime, I don't want to throw the data off.

# %%
# dropping rows with null values 

df.dropna(axis=0, inplace= True)

# %%
#to check if the 34 rows dropped and we have no null values

df.isna().sum()
# Out:
# genre_ids            0
# runtime_minutes      0
# title_and_id         0
# release_date_y       0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# total_gross          0
# net_profit           0
# ROI                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2864 entries, 0 to 2958
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          2864 non-null   object
#  1   runtime_minutes    2864 non-null   float64
#  2   title_and_id       2864 non-null   object
#  3   release_date_y     2864 non-null   object
#  4   production_budget  2864 non-null   int64
#  5   domestic_gross     2864 non-null   int64
#  6   worldwide_gross    2864 non-null   int64
#  7   total_gross        2864 non-null   int64
#  8   net_profit         2864 non-null   int64
#  9   ROI                2864 non-null   float64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 246.1+ KB

# %% [markdown]
# ## Removing duplicates

# %%
# to show how many duplicates we have as a slice of the current df

df[df.duplicated(subset = df.drop('genre_ids', axis = 1).columns, 
                )].sort_values(by = 'title_and_id')
# Out:
#                                genre_ids  runtime_minutes  \
# 1529                            [Horror]             84.0
# 1525            [Crime, Drama, Thriller]             84.0
# 2667                            [Comedy]            104.0
# 656                        [Documentary]             98.0
# 2432                    [Drama, Fantasy]            108.0
# ...                                  ...              ...
# 1494  [Adventure, Fantasy, War, Romance]             60.0
# 1495  [Adventure, Fantasy, War, Romance]             75.0
# 2648                     [Drama, Family]            113.0
# 2213                             [Drama]            123.0
# 398         [Comedy, Adventure, Fantasy]            102.0
#
#                            title_and_id release_date_y  production_budget  \
# 1529       24 Hours to Die id tt3747550   Sep 18, 2015            2000000
# 1525       24 Hours to Die id tt3747550   Sep 18, 2015            2000000
# ...

# %%
# dropping duplicate rows that are about the same film by using the above 
# subset (which checks for everything except matching values in the 
# 'genre_ids' columns.) 

df.drop_duplicates(subset = df.drop('genre_ids', axis = 1).columns,
                   inplace = True)

# %%
# checking to make sure the duplicates were dropped. 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2201 entries, 0 to 2955
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          2201 non-null   object
#  1   runtime_minutes    2201 non-null   float64
#  2   title_and_id       2201 non-null   object
#  3   release_date_y     2201 non-null   object
#  4   production_budget  2201 non-null   int64
#  5   domestic_gross     2201 non-null   int64
#  6   worldwide_gross    2201 non-null   int64
#  7   total_gross        2201 non-null   int64
#  8   net_profit         2201 non-null   int64
#  9   ROI                2201 non-null   float64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 189.1+ KB

# %%
df
# Out:
#                                     genre_ids  runtime_minutes  \
# 0     [Fantasy, Adventure, Animation, Family]             98.0
# 1        [Adventure, Action, Science Fiction]            124.0
# 2        [Action, Science Fiction, Adventure]            148.0
# 3                [Adventure, Fantasy, Family]            118.0
# 4                 [Animation, Family, Comedy]            103.0
# ...                                       ...              ...
# 2951              [Horror, Mystery, Thriller]            145.0
# 2952              [Horror, Mystery, Thriller]            115.0
# 2953              [Horror, Mystery, Thriller]             80.0
# 2954                [Action, Science Fiction]             91.0
# 2955                                       []             89.0
#
#                                            title_and_id release_date_y  \
# 0                 How to Train Your Dragon id tt0892769   Mar 26, 2010
# ...

# %% [markdown]
# After cleaning and removing null values and duplicates, this analysis will use a dataset the size of 2,864 films.

# %% [markdown]
# # Recommendations:

# %% [markdown]
# ## Genre recommendations

# %%
#first we need to use .explode to make a row for each genre that each film
#falls into and so we can compare genres side by side based on total gross, 
#net profit and ROI 

df_exploded = df.explode('genre_ids', ignore_index=False)
df_exploded.head()
# Out:
#    genre_ids  runtime_minutes                           title_and_id  \
# 0    Fantasy             98.0  How to Train Your Dragon id tt0892769
# 0  Adventure             98.0  How to Train Your Dragon id tt0892769
# 0  Animation             98.0  How to Train Your Dragon id tt0892769
# 0     Family             98.0  How to Train Your Dragon id tt0892769
# 1  Adventure            124.0                Iron Man 2 id tt1228705
#
#   release_date_y  production_budget  domestic_gross  worldwide_gross  \
# 0   Mar 26, 2010          165000000       217581232        494870992
# 0   Mar 26, 2010          165000000       217581232        494870992
# 0   Mar 26, 2010          165000000       217581232        494870992
# 0   Mar 26, 2010          165000000       217581232        494870992
# 1    May 7, 2010          170000000       312433331        621156389
#
#    total_gross  net_profit         ROI
# 0    712452224   547452224  331.789227
# 0    712452224   547452224  331.789227
# ...

# %%
# seeing the shape of the exploded dataframe 

df_exploded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5118 entries, 0 to 2955
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          5118 non-null   object
#  1   runtime_minutes    5118 non-null   float64
#  2   title_and_id       5118 non-null   object
#  3   release_date_y     5118 non-null   object
#  4   production_budget  5118 non-null   int64
#  5   domestic_gross     5118 non-null   int64
#  6   worldwide_gross    5118 non-null   int64
#  7   total_gross        5118 non-null   int64
#  8   net_profit         5118 non-null   int64
#  9   ROI                5118 non-null   float64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 439.8+ KB

# %%
# slicing out the rows where the genre was left blank
# (these rows didn't pop as null values although they are equivilant to null)

null_genre = df_exploded.loc[df_exploded['genre_ids'] == '']
null_genre
# Out:
#      genre_ids  runtime_minutes                 title_and_id release_date_y  \
# 360                        80.0         Plastic id tt1691450   Sep 26, 2014
# 361                        78.0         Plastic id tt2554700   Sep 26, 2014
# 362                       102.0         Plastic id tt2556874   Sep 26, 2014
# 373                        85.0         Monster id tt1617136   Dec 24, 2003
# 374                        90.0         Monster id tt6840904   Dec 24, 2003
# ...        ...              ...                          ...            ...
# 1954                       90.0             Red id tt8851190   Oct 15, 2010
# 1957                       88.0     Breaking In id tt7137846   May 11, 2018
# 2280                       82.0    Diamond Ruff id tt2111292   Dec 31, 2014
# 2304                       75.0  Graduation Day id tt2616818    May 1, 1981
# 2955                       89.0         The Box id tt1728200    Nov 6, 2009
#
# ...

# %%
# removing the rows we sliced above 

df_exploded.drop(labels = null_genre.index, inplace = True)

# %%
# checking to make sure those rows were removed 

df_exploded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5056 entries, 0 to 2954
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          5056 non-null   object
#  1   runtime_minutes    5056 non-null   float64
#  2   title_and_id       5056 non-null   object
#  3   release_date_y     5056 non-null   object
#  4   production_budget  5056 non-null   int64
#  5   domestic_gross     5056 non-null   int64
#  6   worldwide_gross    5056 non-null   int64
#  7   total_gross        5056 non-null   int64
#  8   net_profit         5056 non-null   int64
#  9   ROI                5056 non-null   float64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 434.5+ KB

# %%
# making a table that shows all the genres and their adverage values,
# sorted by net profit

by_genre_net = df_exploded.groupby(by='genre_ids', axis=0).mean()\
.sort_values('net_profit', ascending=False)
by_genre_net
# Out:
#                  runtime_minutes  production_budget  domestic_gross  \
# genre_ids
# Animation              95.351351       9.040991e+07    1.328418e+08
# Adventure             110.701538       1.010752e+08    1.124018e+08
# Fantasy               108.731959       9.148041e+07    1.071063e+08
# Family                 98.774869       8.051963e+07    1.074798e+08
# Science Fiction       107.185185       6.833975e+07    7.924039e+07
# Action                108.844130       7.340315e+07    7.896383e+07
# Comedy                100.841244       3.535768e+07    5.192640e+07
# War                   112.522727       3.870682e+07    4.464108e+07
# Crime                 107.146245       3.452103e+07    3.941484e+07
# Western               109.148148       5.058519e+07    4.334205e+07
# Music                 107.239130       2.490000e+07    4.031065e+07
# TV Movie               98.000000       1.791667e+07    3.478072e+07
# Thriller              102.034539       2.954697e+07    3.376534e+07
# ...

# %%
# making a plot to visualize the above table so we can easily see which 
# genres dominate net profits 

values = by_genre_net['net_profit'] 
colors = ['grey' if (x < 2.838668e+08	) else 'blue' for x in values ]

sns.set_style(style = 'white')

plt.figure(figsize=(8,8))

ax = sns.barplot(data = df_exploded, x = "net_profit", y = "genre_ids", 
           order = by_genre_net.index, palette=colors)
ax.set(xlabel="Average Net Profit in Hundred Millions", ylabel = "Genre", 
       title = "Net Profit by Genre")

# making sure my labels don't get cut-off

plt.tight_layout();

# specifying the scientific notation to units in regular English 
# investigate this blank bar

# %% [markdown]
# The takeaway here is that animation, adventure, fantasy and family are the top four genres by close to 70 million dollars.

# %% [markdown]
# ### CITATION: color coding
#
# adapted from: https://stackoverflow.com/questions/31074758/how-to-set-a-different-color-to-the-largest-bar-in-a-seaborn-barplot

# %% [markdown]
# ## Release Date

# %%
# making a new series called release_date that only contains films if they are 
# in the Animation, Adventure, Fantasy or Family genres for further analysis 

release_date = df_exploded['genre_ids'].isin(['Animation', 'Adventure',
                                              'Fantasy', 'Family'])

release_date.value_counts()
# Out:
# False    4235
# True      821
# Name: genre_ids, dtype: int64

# %%
# slicing out the series from df_exploded and making it it's own dataframe

release_date = df_exploded[release_date]
release_date.head()
# Out:
#    genre_ids  runtime_minutes                           title_and_id  \
# 0    Fantasy             98.0  How to Train Your Dragon id tt0892769
# 0  Adventure             98.0  How to Train Your Dragon id tt0892769
# 0  Animation             98.0  How to Train Your Dragon id tt0892769
# 0     Family             98.0  How to Train Your Dragon id tt0892769
# 1  Adventure            124.0                Iron Man 2 id tt1228705
#
#   release_date_y  production_budget  domestic_gross  worldwide_gross  \
# 0   Mar 26, 2010          165000000       217581232        494870992
# 0   Mar 26, 2010          165000000       217581232        494870992
# 0   Mar 26, 2010          165000000       217581232        494870992
# 0   Mar 26, 2010          165000000       217581232        494870992
# 1    May 7, 2010          170000000       312433331        621156389
#
#    total_gross  net_profit         ROI
# 0    712452224   547452224  331.789227
# 0    712452224   547452224  331.789227
# ...

# %%
# turning release_date_y into datetime format 

release_date['date_time'] = pd.to_datetime(release_date['release_date_y'])
release_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 821 entries, 0 to 2947
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          821 non-null    object
#  1   runtime_minutes    821 non-null    float64
#  2   title_and_id       821 non-null    object
#  3   release_date_y     821 non-null    object
#  4   production_budget  821 non-null    int64
#  5   domestic_gross     821 non-null    int64
#  6   worldwide_gross    821 non-null    int64
#  7   total_gross        821 non-null    int64
#  8   net_profit         821 non-null    int64
#  9   ROI                821 non-null    float64
#  10  date_time          821 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(5), object(3)
# memory usage: 77.0+ KB
# <ipython-input-84-6f9bb6a9cb62>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#isolating the release month from that datetime column 

release_date['month_num'] = release_date['date_time'].dt.month
release_date.head()
# Out:
# <ipython-input-85-11899e521ef7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   release_date['month_num'] = release_date['date_time'].dt.month
#    genre_ids  runtime_minutes                           title_and_id  \
# 0    Fantasy             98.0  How to Train Your Dragon id tt0892769
# 0  Adventure             98.0  How to Train Your Dragon id tt0892769
# 0  Animation             98.0  How to Train Your Dragon id tt0892769
# 0     Family             98.0  How to Train Your Dragon id tt0892769
# 1  Adventure            124.0                Iron Man 2 id tt1228705
#
#   release_date_y  production_budget  domestic_gross  worldwide_gross  \
# 0   Mar 26, 2010          165000000       217581232        494870992
# ...

# %%
# putting a column for the name of the month for readability 

release_date['month_name'] = release_date['date_time'].dt.month_name()
release_date.head()
# Out:
# <ipython-input-86-152d7827001d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   release_date['month_name'] = release_date['date_time'].dt.month_name()
#    genre_ids  runtime_minutes                           title_and_id  \
# 0    Fantasy             98.0  How to Train Your Dragon id tt0892769
# 0  Adventure             98.0  How to Train Your Dragon id tt0892769
# 0  Animation             98.0  How to Train Your Dragon id tt0892769
# 0     Family             98.0  How to Train Your Dragon id tt0892769
# 1  Adventure            124.0                Iron Man 2 id tt1228705
#
#   release_date_y  production_budget  domestic_gross  worldwide_gross  \
# 0   Mar 26, 2010          165000000       217581232        494870992
# ...

# %%
#making a pivot table to aggrigate the data based on genre

pivot = pd.pivot_table(release_date, values='net_profit', index='month_name', 
                       columns='genre_ids')
pivot
# Out:
# genre_ids      Adventure     Animation        Family       Fantasy
# month_name
# April       3.639112e+08  3.594065e+08  3.652238e+08  4.168243e+08
# August      1.785756e+08  5.650822e+07  8.087768e+07  2.192492e+08
# December    3.378595e+08  2.264141e+08  1.731402e+08  3.304541e+08
# February    1.855495e+08  3.756855e+08  2.598824e+08  1.908724e+08
# January     1.220691e+08  1.907414e+08  1.482089e+08  7.999303e+07
# July        3.783961e+08  6.644173e+08  3.952794e+08  2.014382e+08
# June        5.011279e+08  7.614652e+08  5.118351e+08  4.908190e+08
# March       2.832314e+08  5.556345e+08  4.403053e+08  3.973046e+08
# May         5.635206e+08  5.934604e+08  3.419126e+08  3.425121e+08
# November    4.324922e+08  4.142573e+08  3.082870e+08  4.424158e+08
# October     1.695030e+08  1.735661e+08  1.292997e+08  9.471312e+07
# September   1.169505e+08  2.287723e+08  2.049232e+08  2.056765e+08

# %%
# I need to make a "total" column temporarily so that I can use those total 
# values to order the months in the pivot table

pivot['total'] = pivot['Adventure'] + pivot['Animation'] + \
                     pivot['Family'] +  pivot['Fantasy']
pivot
# Out:
# genre_ids      Adventure     Animation        Family       Fantasy  \
# month_name
# April       3.639112e+08  3.594065e+08  3.652238e+08  4.168243e+08
# August      1.785756e+08  5.650822e+07  8.087768e+07  2.192492e+08
# December    3.378595e+08  2.264141e+08  1.731402e+08  3.304541e+08
# February    1.855495e+08  3.756855e+08  2.598824e+08  1.908724e+08
# January     1.220691e+08  1.907414e+08  1.482089e+08  7.999303e+07
# July        3.783961e+08  6.644173e+08  3.952794e+08  2.014382e+08
# June        5.011279e+08  7.614652e+08  5.118351e+08  4.908190e+08
# March       2.832314e+08  5.556345e+08  4.403053e+08  3.973046e+08
# May         5.635206e+08  5.934604e+08  3.419126e+08  3.425121e+08
# November    4.324922e+08  4.142573e+08  3.082870e+08  4.424158e+08
# October     1.695030e+08  1.735661e+08  1.292997e+08  9.471312e+07
# September   1.169505e+08  2.287723e+08  2.049232e+08  2.056765e+08
#
# genre_ids          total
# month_name
# April       1.505366e+09
# ...

# %%
# sorting by those totalled values

pivot.sort_values('total', inplace = True, ascending=False)
pivot
# Out:
# genre_ids      Adventure     Animation        Family       Fantasy  \
# month_name
# June        5.011279e+08  7.614652e+08  5.118351e+08  4.908190e+08
# May         5.635206e+08  5.934604e+08  3.419126e+08  3.425121e+08
# March       2.832314e+08  5.556345e+08  4.403053e+08  3.973046e+08
# July        3.783961e+08  6.644173e+08  3.952794e+08  2.014382e+08
# November    4.324922e+08  4.142573e+08  3.082870e+08  4.424158e+08
# April       3.639112e+08  3.594065e+08  3.652238e+08  4.168243e+08
# December    3.378595e+08  2.264141e+08  1.731402e+08  3.304541e+08
# February    1.855495e+08  3.756855e+08  2.598824e+08  1.908724e+08
# September   1.169505e+08  2.287723e+08  2.049232e+08  2.056765e+08
# October     1.695030e+08  1.735661e+08  1.292997e+08  9.471312e+07
# January     1.220691e+08  1.907414e+08  1.482089e+08  7.999303e+07
# August      1.785756e+08  5.650822e+07  8.087768e+07  2.192492e+08
#
# genre_ids          total
# month_name
# June        2.265247e+09
# ...

# %%
# removing the total column once it's served it's purpose so I can proceed to 
# graph the information within this aggregated data

pivot.drop(columns = 'total', inplace = True)
pivot
# Out:
# genre_ids      Adventure     Animation        Family       Fantasy
# month_name
# June        5.011279e+08  7.614652e+08  5.118351e+08  4.908190e+08
# May         5.635206e+08  5.934604e+08  3.419126e+08  3.425121e+08
# March       2.832314e+08  5.556345e+08  4.403053e+08  3.973046e+08
# July        3.783961e+08  6.644173e+08  3.952794e+08  2.014382e+08
# November    4.324922e+08  4.142573e+08  3.082870e+08  4.424158e+08
# April       3.639112e+08  3.594065e+08  3.652238e+08  4.168243e+08
# December    3.378595e+08  2.264141e+08  1.731402e+08  3.304541e+08
# February    1.855495e+08  3.756855e+08  2.598824e+08  1.908724e+08
# September   1.169505e+08  2.287723e+08  2.049232e+08  2.056765e+08
# October     1.695030e+08  1.735661e+08  1.292997e+08  9.471312e+07
# January     1.220691e+08  1.907414e+08  1.482089e+08  7.999303e+07
# August      1.785756e+08  5.650822e+07  8.087768e+07  2.192492e+08

# %%
# making a plot to show the above pivot table as a stacked bar chart

ax = pivot.plot(kind='bar', figsize=(7, 7), stacked=True)

#ax.axhline(1500000000, color = "blue")
#ax.axhline(1900000000, color = "green")

ax.set(xlabel = "Month", ylabel = "Net Profit in Billions", 
       title = "Average Net Profit By Genre By Month")

plt.xticks(rotation = 45);

# %% [markdown]
# The takeaway here is to release films in June, where the average film in this genre made over 1.9 billion dollars (shown by the green line.) If there is a delay in production due to Covid-19, I'd recommend these months as backup choices: May, March, July, November or April.
#
# Interesting find: Fantasy films do not do well in July compared to other high earning months.

# %% [markdown]
# ## Runtime of Film

# %%
# taking a look at the shape of release_date 

release_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 821 entries, 0 to 2947
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          821 non-null    object
#  1   runtime_minutes    821 non-null    float64
#  2   title_and_id       821 non-null    object
#  3   release_date_y     821 non-null    object
#  4   production_budget  821 non-null    int64
#  5   domestic_gross     821 non-null    int64
#  6   worldwide_gross    821 non-null    int64
#  7   total_gross        821 non-null    int64
#  8   net_profit         821 non-null    int64
#  9   ROI                821 non-null    float64
#  10  date_time          821 non-null    datetime64[ns]
#  11  month_num          821 non-null    int64
#  12  month_name         821 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(6), object(4)
# memory usage: 89.8+ KB

# %%
# all movies in this data set are between 30 and 180
# making a visualization to represent the films in this dataset based
# on Net Profit in billions and runtime. 

plt.figure(figsize=(10,10))

runtime_plot = sns.regplot(data = release_date, x = 'runtime_minutes', 
                 y = 'net_profit', color = 'green',
                 scatter_kws={'alpha':0.3})

runtime_plot.set(xlabel = 'Runtime Minutes', 
                 ylabel = 'Net Profit in Billions', 
                 title = "Net Profit of Movies by Runtime Minutes");

# %% [markdown]
# This doesn't tell us very much so instead let's sort runtime minutes into categorical data instead

# %%
# Making a list of bin edges

bins = [ 60, 90, 120, 150, 180]
bins
# Out:
# [60, 90, 120, 150, 180]

# %%
# Making a list of labels to go with those bins 

labels = ['Sixty', 'One hundred twenty',
          'One hundred fifty', 'One hundred eighty']

# %%
# cutting the data into those bins, using both bins and labels

cut_data, bin_edges = pd.cut(release_date['runtime_minutes'], bins = bins,
                              labels = labels, retbins = True)
bin_edges
# Out:
# array([ 60,  90, 120, 150, 180])

# %%
# Taking a look to see if our bins are a new column and labeled

release_date['runtime_bins']= cut_data
release_date.head()
# Out:
# <ipython-input-105-1b6b290c6298>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   release_date['runtime_bins']= cut_data
#    genre_ids  runtime_minutes                           title_and_id  \
# 0    Fantasy             98.0  How to Train Your Dragon id tt0892769
# 0  Adventure             98.0  How to Train Your Dragon id tt0892769
# 0  Animation             98.0  How to Train Your Dragon id tt0892769
# 0     Family             98.0  How to Train Your Dragon id tt0892769
# 1  Adventure            124.0                Iron Man 2 id tt1228705
#
#   release_date_y  production_budget  domestic_gross  worldwide_gross  \
# 0   Mar 26, 2010          165000000       217581232        494870992
# ...

# %%
runtime_df = release_date.groupby(by='runtime_bins').mean()
runtime_df = runtime_df.reset_index()
runtime_df
# Out:
#          runtime_bins  runtime_minutes  production_budget  domestic_gross  \
# 0               Sixty        84.415584       5.798247e+07    7.235175e+07
# 1  One hundred twenty       102.746032       8.905279e+07    1.043638e+08
# 2   One hundred fifty       132.417266       1.387950e+08    1.827653e+08
# 3  One hundred eighty       161.157895       1.377368e+08    1.543482e+08
#
#    worldwide_gross   total_gross    net_profit         ROI  month_num
# 0     2.091152e+08  2.814670e+08  2.234845e+08  315.149988   6.948052
# 1     2.870365e+08  3.914003e+08  3.023476e+08  408.572564   6.599206
# 2     4.979914e+08  6.807567e+08  5.419617e+08  486.097270   7.000000
# 3     5.215815e+08  6.759298e+08  5.381929e+08  255.530136   8.789474

# %%
# taking a look at the average net profit in hundred-thousands by bin

runtime_df['net_profit']
# Out:
# 0    2.234845e+08
# 1    3.023476e+08
# 2    5.419617e+08
# 3    5.381929e+08
# Name: net_profit, dtype: float64

# %%
# sorting this aggregated data from highest to lowest by Net Profit 

runtime_df.sort_values(by = 'net_profit', inplace = True) 
runtime_df
# Out:
#          runtime_bins  runtime_minutes  production_budget  domestic_gross  \
# 0               Sixty        84.415584       5.798247e+07    7.235175e+07
# 1  One hundred twenty       102.746032       8.905279e+07    1.043638e+08
# 3  One hundred eighty       161.157895       1.377368e+08    1.543482e+08
# 2   One hundred fifty       132.417266       1.387950e+08    1.827653e+08
#
#    worldwide_gross   total_gross    net_profit         ROI  month_num
# 0     2.091152e+08  2.814670e+08  2.234845e+08  315.149988   6.948052
# 1     2.870365e+08  3.914003e+08  3.023476e+08  408.572564   6.599206
# 3     5.215815e+08  6.759298e+08  5.381929e+08  255.530136   8.789474
# 2     4.979914e+08  6.807567e+08  5.419617e+08  486.097270   7.000000

# %%
# visualizing the above data 

plt.figure(figsize=(8,8))

ax = sns.barplot(data = release_date, x = 'runtime_bins', y = 'net_profit')
plt.xticks(rotation=45)

ax.set(xlabel = 'Runtime Bins', ylabel = 'Average Net Profit in 100K Dollars', 
       title = "Net Profit by Runtime Bin")
    
plt.tight_layout();
# this will help my labels not get cut-off

# %% [markdown]
# Here the important piece of information is that films between 120-150 minutes do better consistently, and movies between 150-180 movies do about as well on average but have a much higher rate of deviation. (It's more likely that films in that range will do either much better or much worse than films in the previous bin.

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ## Three Business Recommendations:

# %% [markdown]
# My three business recommendations to Microsoft Studios would be:
# 1) Focus on making films that are a combination of animation, fantasy, adventure, and family. There are many examples of the combination of these genres already, (Pixar Studios being the best example of having luck here.)
#
# 2) Release this film in June, May, March of any genre, or July with an emphasis on non-Fantasy films (which, interestingly do much better in November.)
#
# 3) Make the movie somewhere within 120-150 minutes long since movies in this range tend to make the most net profit on average with the most consistency.

# %% [markdown]
# ## Future Work

# %% [markdown]
# Future work: I'd love to, if the project parameters were a bit larger, take a look at what studios tend to do best within the three recommendations I've already given. I'd also love an opportunity to work with review data and see how films that fit these three categories are normally rated and reviewed.
